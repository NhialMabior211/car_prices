# %%
import pandas as pd 
import numpy as np

# %%
## loading the data

train = pd.read_csv("C:\\Users\\dutma\\Downloads\\train.csv")

# %%
test = pd.read_csv("C:\\Users\\dutma\\Downloads\\test.csv")

# %%
train.head()
# Out:
#    Unnamed: 0  Kilometeres Fuel_Type  Doors  Automatic  HorsePower  \
# 0           1        46986    Diesel      3          0          90
# 1           7        94612    Diesel      3          0          90
# 2           9        19700    Petrol      3          0         192
# 3          12        43610    Petrol      3          0         192
# 4          15        34131    Petrol      3          0         192
#
#    MetallicCol    CC    Wt  SellingPrice  Age
# 0            1  2000  1165         13500   23
# 1            1  2000  1245         16900   27
# 2            0  1800  1185         21500   27
# 3            0  1800  1185         19950   22
# 4            1  1800  1185         22500   32

# %%
# removing the unneccesary columns


train.drop(train.columns[0], axis = 1, inplace = True)

# %%
train.head()
# Out:
#    Kilometeres Fuel_Type  Doors  Automatic  HorsePower  MetallicCol    CC  \
# 0        46986    Diesel      3          0          90            1  2000
# 1        94612    Diesel      3          0          90            1  2000
# 2        19700    Petrol      3          0         192            0  1800
# 3        43610    Petrol      3          0         192            0  1800
# 4        34131    Petrol      3          0         192            1  1800
#
#      Wt  SellingPrice  Age
# 0  1165         13500   23
# 1  1245         16900   27
# 2  1185         21500   27
# 3  1185         19950   22
# 4  1185         22500   32

# %%
test.drop(test.columns[0], axis = 1, inplace = True)

# %%
test.head()
# Out:
#    Kilometeres Fuel_Type  Doors  Automatic  HorsePower  MetallicCol    CC  \
# 0       140700    Diesel      5          0          69            1  1900
# 1        77270    Petrol      4          0         110            1  1600
# 2        33230    Petrol      3          0         110            0  1600
# 3        36269    Petrol      5          0         110            1  1600
# 4        70932    Petrol      3          0         110            1  1600
#
#      Wt  SellingPrice  Age
# 0  1110          7750   48
# 1  1035         11950   54
# 2  1050         11500   55
# 3  1075         10750   36
# 4  1050          7450   77

# %%
# changing the categorical variables into quantative 

dummy = pd.get_dummies(train, columns =['Fuel_Type'])

# %%
dummy.head()
# Out:
#    Kilometeres  Doors  Automatic  HorsePower  MetallicCol    CC    Wt  \
# 0        46986      3          0          90            1  2000  1165
# 1        94612      3          0          90            1  2000  1245
# 2        19700      3          0         192            0  1800  1185
# 3        43610      3          0         192            0  1800  1185
# 4        34131      3          0         192            1  1800  1185
#
#    SellingPrice  Age  Fuel_Type_CNG  Fuel_Type_Diesel  Fuel_Type_Petrol
# 0         13500   23          False              True             False
# 1         16900   27          False              True             False
# 2         21500   27          False             False              True
# 3         19950   22          False             False              True
# 4         22500   32          False             False              True

# %%
train_d = dummy.astype(int)

# %%
train_d.head()
# Out:
#    Kilometeres  Doors  Automatic  HorsePower  MetallicCol    CC    Wt  \
# 0        46986      3          0          90            1  2000  1165
# 1        94612      3          0          90            1  2000  1245
# 2        19700      3          0         192            0  1800  1185
# 3        43610      3          0         192            0  1800  1185
# 4        34131      3          0         192            1  1800  1185
#
#    SellingPrice  Age  Fuel_Type_CNG  Fuel_Type_Diesel  Fuel_Type_Petrol
# 0         13500   23              0                 1                 0
# 1         16900   27              0                 1                 0
# 2         21500   27              0                 0                 1
# 3         19950   22              0                 0                 1
# 4         22500   32              0                 0                 1

# %%
test_d = pd.get_dummies(test, columns =['Fuel_Type']).astype(int)

# %%
test_d.head()
# Out:
#    Kilometeres  Doors  Automatic  HorsePower  MetallicCol    CC    Wt  \
# 0       140700      5          0          69            1  1900  1110
# 1        77270      4          0         110            1  1600  1035
# 2        33230      3          0         110            0  1600  1050
# 3        36269      5          0         110            1  1600  1075
# 4        70932      3          0         110            1  1600  1050
#
#    SellingPrice  Age  Fuel_Type_CNG  Fuel_Type_Diesel  Fuel_Type_Petrol
# 0          7750   48              0                 1                 0
# 1         11950   54              0                 0                 1
# 2         11500   55              0                 0                 1
# 3         10750   36              0                 0                 1
# 4          7450   77              0                 0                 1

# %%
train_d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 958 entries, 0 to 957
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Kilometeres       958 non-null    int32
#  1   Doors             958 non-null    int32
#  2   Automatic         958 non-null    int32
#  3   HorsePower        958 non-null    int32
#  4   MetallicCol       958 non-null    int32
#  5   CC                958 non-null    int32
#  6   Wt                958 non-null    int32
#  7   SellingPrice      958 non-null    int32
#  8   Age               958 non-null    int32
#  9   Fuel_Type_CNG     958 non-null    int32
#  10  Fuel_Type_Diesel  958 non-null    int32
#  11  Fuel_Type_Petrol  958 non-null    int32
# dtypes: int32(12)
# memory usage: 45.0 KB

# %%
train_d.isnull().sum()
# Out:
# Kilometeres         0
# Doors               0
# Automatic           0
# HorsePower          0
# MetallicCol         0
# CC                  0
# Wt                  0
# SellingPrice        0
# Age                 0
# Fuel_Type_CNG       0
# Fuel_Type_Diesel    0
# Fuel_Type_Petrol    0
# dtype: int64

# %%
train_d.describe()
# Out:
#          Kilometeres       Doors   Automatic  HorsePower  MetallicCol  \
# count     958.000000  958.000000  958.000000  958.000000   958.000000
# mean    69067.598121    4.009395    0.056367  101.549061     0.669102
# std     37082.673742    0.955059    0.230750   14.556315     0.470782
# min         1.000000    2.000000    0.000000   69.000000     0.000000
# 25%     43472.000000    3.000000    0.000000   90.000000     0.000000
# 50%     63547.000000    4.000000    0.000000  110.000000     1.000000
# 75%     87580.000000    5.000000    0.000000  110.000000     1.000000
# max    243000.000000    5.000000    1.000000  192.000000     1.000000
#
#                 CC           Wt  SellingPrice         Age  Fuel_Type_CNG  \
# count   958.000000   958.000000    958.000000  958.000000     958.000000
# mean   1566.651357  1072.701461  10666.893528   56.463466       0.011482
# std     184.850459    55.235835   3633.781940   18.332019       0.106594
# ...

# %%
## Expolatory Data Aanlysis

train_d.corr()
# Out:
#                   Kilometeres     Doors  Automatic  HorsePower  MetallicCol  \
# Kilometeres          1.000000 -0.037574  -0.097628   -0.329155    -0.077100
# Doors               -0.037574  1.000000  -0.016630    0.116733     0.090585
# Automatic           -0.097628 -0.016630   1.000000    0.037441    -0.049360
# HorsePower          -0.329155  0.116733   0.037441    1.000000     0.067252
# MetallicCol         -0.077100  0.090585  -0.049360    0.067252     1.000000
# CC                   0.309269  0.111654  -0.044713    0.042837     0.055372
# Wt                  -0.035067  0.282493   0.071991    0.074950     0.060330
# SellingPrice        -0.554376  0.180088   0.055216    0.291650     0.083892
# Age                  0.484124 -0.129402   0.003205   -0.138730    -0.087669
# Fuel_Type_CNG        0.169254  0.029732   0.016142    0.062604     0.034147
# Fuel_Type_Diesel     0.403781  0.003743  -0.083904   -0.544692     0.003039
# ...

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
sns.pairplot(train_d)

# %%
train_d.head()
# Out:
#    Kilometeres  Doors  Automatic  HorsePower  MetallicCol    CC    Wt  \
# 0        46986      3          0          90            1  2000  1165
# 1        94612      3          0          90            1  2000  1245
# 2        19700      3          0         192            0  1800  1185
# 3        43610      3          0         192            0  1800  1185
# 4        34131      3          0         192            1  1800  1185
#
#    SellingPrice  Age  Fuel_Type_CNG  Fuel_Type_Diesel  Fuel_Type_Petrol
# 0         13500   23              0                 1                 0
# 1         16900   27              0                 1                 0
# 2         21500   27              0                 0                 1
# 3         19950   22              0                 0                 1
# 4         22500   32              0                 0                 1

# %%
 train_d.drop(columns = ['SellingPrice'],inplace = True)

# %%
x_train = train_d

x_train.head()
# Out:
#    Kilometeres  Doors  Automatic  HorsePower  MetallicCol    CC    Wt  Age  \
# 0        46986      3          0          90            1  2000  1165   23
# 1        94612      3          0          90            1  2000  1245   27
# 2        19700      3          0         192            0  1800  1185   27
# 3        43610      3          0         192            0  1800  1185   22
# 4        34131      3          0         192            1  1800  1185   32
#
#    Fuel_Type_CNG  Fuel_Type_Diesel  Fuel_Type_Petrol
# 0              0                 1                 0
# 1              0                 1                 0
# 2              0                 0                 1
# 3              0                 0                 1
# 4              0                 0                 1

# %%
 test_d.drop(columns = ['SellingPrice'], inplace = True)

# %%
x_test = test_d

# %%
x_test.head()
# Out:
#    Kilometeres  Doors  Automatic  HorsePower  MetallicCol    CC    Wt  Age  \
# 0       140700      5          0          69            1  1900  1110   48
# 1        77270      4          0         110            1  1600  1035   54
# 2        33230      3          0         110            0  1600  1050   55
# 3        36269      5          0         110            1  1600  1075   36
# 4        70932      3          0         110            1  1600  1050   77
#
#    Fuel_Type_CNG  Fuel_Type_Diesel  Fuel_Type_Petrol
# 0              0                 1                 0
# 1              0                 0                 1
# 2              0                 0                 1
# 3              0                 0                 1
# 4              0                 0                 1

# %%
y_train = train['SellingPrice']

# %%
y_train.head()
# Out:
# 0    13500
# 1    16900
# 2    21500
# 3    19950
# 4    22500
# Name: SellingPrice, dtype: int64

# %%
y_test= test['SellingPrice']

# %%
y_test.head()
# Out:
# 0     7750
# 1    11950
# 2    11500
# 3    10750
# 4     7450
# Name: SellingPrice, dtype: int64

# %%
## standardise the dataset

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
x_train = scaler.fit_transform(x_train)

# %%
x_train
# Out:
# array([[-0.59578045, -1.05744461, -0.24440645, ..., -0.10777582,
#          2.91292783, -2.74837614],
#        [ 0.68920986, -1.05744461, -0.24440645, ..., -0.10777582,
#          2.91292783, -2.74837614],
#        [-1.33198012, -1.05744461, -0.24440645, ..., -0.10777582,
#         -0.34329721,  0.36385122],
#        ...,
#        [-1.30920828, -1.05744461, -0.24440645, ..., -0.10777582,
#         -0.34329721,  0.36385122],
#        [-1.35086672, -1.05744461, -0.24440645, ..., -0.10777582,
#         -0.34329721,  0.36385122],
#        [-1.40709483, -1.05744461, -0.24440645, ..., -0.10777582,
#         -0.34329721,  0.36385122]])

# %%
x_test = scaler.fit_transform(x_test)

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
## print the coefficients

print(reg.coef_)
# Out:
# [ -614.67173839    44.33653647    81.92700904   984.0468284
#    -19.60516187  -811.35019525   958.12789039 -2290.82296449
#   -293.58428276   507.80234784  -388.00200426]

# %%
reg.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %%
reg_pred = reg.predict(x_test)

# %%
reg_pred
# Out:
# array([10160.07708853,  9930.06138586, 10817.5481293 , 13610.60561036,
#         7529.54597471, 11744.75507911,  9623.37727047, 18594.30640322,
#        12185.80814469,  9206.46975636, 23790.67457137, 10440.13600869,
#         7654.10546864,  9951.57609304,  8350.74840389, 16865.03678154,
#        17191.72864478, 12567.72985445,  8697.23785719, 10346.40653356,
#         7484.09553333, 13170.31556834,  7519.92836685, 16541.26145569,
#        12446.90785735, 13953.37896993, 10149.9535798 , 12976.54639365,
#         7916.41770016, 12834.79131112,  8844.37943554, 11888.88360496,
#        18591.55197658,  9766.27200784,  7534.81886011,  7361.54324   ,
#        10377.6692863 , 13934.88176592,  7627.87377172, 10922.83297048,
#         8490.1249591 ,  8621.75313968, 12707.85463717,  8682.07156577,
#        17617.17396705,  9320.83058205,  7441.31650369, 10766.39950478,
#         7463.66840516,  4843.84915648,  7494.76656588,  9451.60318416,
# ...

# %%
# plot a scatter plot for the prediction
plt.scatter(y_test, reg_pred)

# %%
## residuals
residuals = y_test - reg_pred
residuals
# Out:
# 0     -2410.077089
# 1      2019.938614
# 2       682.451871
# 3     -2860.605610
# 4       -79.545975
#           ...
# 473    2083.320779
# 474     430.782136
# 475   -1169.976786
# 476    1766.324144
# 477    3314.598775
# Name: SellingPrice, Length: 478, dtype: float64

# %%
sns.displot(residuals, kind = 'kde')

# %%
#scatter plot with respect to prediction and residuals

plt.scatter(reg_pred,residuals)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %%
print(mean_squared_error(y_test,reg_pred))
print(mean_absolute_error(y_test,reg_pred))
# Out:
# 1518848.5985463117
# 946.8205928881346

# %%
#R square and adjusted R square

from sklearn.metrics import r2_score
score = r2_score(y_test,reg_pred)

# %%
print(score)
# Out:
# 0.8834448819959293

# %% [markdown]
# Pickling The Model file for Deployment

# %%
import pickle

# %%
pickle.dump(reg,open('regmodel.pkl','wb'))
